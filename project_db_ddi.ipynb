# %% [markdown]
# ## Chargement des librairies à utiliser

# %%
import pandas as pd
import numpy as np
import itertools
import lxml.etree as ET
from pathlib import Path  
import glob

# %% [markdown]
# ## Analyse exploratoire de la base de données

# %%
df = pd.read_csv(r'C:/Users/Utilisateur/Desktop/Projet_ordonance/PRESCRIPTIONS.csv')
df
# Out:
#         row_id  subject_id  hadm_id  icustay_id            startdate  \
# 0        32600       42458   159647         NaN  2146-07-21 00:00:00
# 1        32601       42458   159647         NaN  2146-07-21 00:00:00
# 2        32602       42458   159647         NaN  2146-07-21 00:00:00
# 3        32603       42458   159647         NaN  2146-07-21 00:00:00
# 4        32604       42458   159647         NaN  2146-07-21 00:00:00
# ...        ...         ...      ...         ...                  ...
# 10393  3609913       42430   100969    210474.0  2142-11-29 00:00:00
# 10394  3609914       42430   100969    210474.0  2142-11-30 00:00:00
# 10395  3609915       42430   100969         NaN  2142-11-26 00:00:00
# 10396  3609916       42430   100969         NaN  2142-11-26 00:00:00
# 10397  3609917       42430   100969         NaN  2142-11-26 00:00:00
#
#                    enddate drug_type                         drug  \
# 0      2146-07-22 00:00:00      MAIN  Pneumococcal Vac Polyvalent
# 1      2146-07-22 00:00:00      MAIN                    Bisacodyl
# 2      2146-07-22 00:00:00      MAIN                    Bisacodyl
# 3      2146-07-22 00:00:00      MAIN                        Senna
# 4      2146-07-21 00:00:00      MAIN     Docusate Sodium (Liquid)
# ...                    ...       ...                          ...
# 10393  2142-11-30 00:00:00      MAIN  Sodium Chloride 0.9%  Flush
# 10394  2142-11-30 00:00:00      MAIN                Acetaminophen
# 10395  2142-11-27 00:00:00      BASE         0.9% Sodium Chloride
# 10396  2142-11-27 00:00:00      BASE                          D5W
# 10397  2142-11-28 00:00:00      BASE        0.83% Sodium Chloride
#
#                      drug_name_poe            drug_name_generic  \
# 0      Pneumococcal Vac Polyvalent  PNEUMOcoccal Vac Polyvalent
# 1                        Bisacodyl                    Bisacodyl
# 2                        Bisacodyl           Bisacodyl (Rectal)
# 3                            Senna                        Senna
# 4         Docusate Sodium (Liquid)     Docusate Sodium (Liquid)
# ...                            ...                          ...
# 10393  Sodium Chloride 0.9%  Flush  Sodium Chloride 0.9%  Flush
# 10394                Acetaminophen       Acetaminophen (Rectal)
# 10395                          NaN                          NaN
# 10396                          NaN                          NaN
# 10397                          NaN                          NaN
#
#       formulary_drug_cd      gsn          ndc     prod_strength dose_val_rx  \
# 0               PNEU25I  48548.0    6494300.0  25mcg/0.5mL Vial         0.5
# 1                 BISA5   2947.0  536338101.0          5 mg Tab          10
# 2               BISA10R   2944.0  574705050.0  10mg Suppository          10
# 3               SENN187  19964.0  904516561.0          1 Tablet           1
# 4              DOCU100L   3017.0  121054410.0      100mg UD Cup         100
# ...                 ...      ...          ...               ...         ...
# 10393         NACLFLUSH      NaN          0.0           Syringe           3
# 10394          ACET650R   4478.0  713016550.0        650mg Supp         650
# 10395            NS1000   1210.0  338004904.0        1000mL Bag        1000
# 10396           HEPBASE      NaN          0.0      HEPARIN BASE         250
# 10397     NICABAGSODCHL      NaN          0.0        200 mL Bag         200
#
#       dose_unit_rx form_val_disp form_unit_disp    route
# 0               mL             1           VIAL       IM
# 1               mg             2            TAB       PO
# 2               mg             1           SUPP       PR
# 3              TAB             1            TAB       PO
# 4               mg             1          UDCUP       PO
# ...            ...           ...            ...      ...
# 10393           mL           0.6            SYR       IV
# 10394           mg             1           SUPP       PR
# 10395           mL             1            BAG       IV
# 10396           mL           250             mL       IV
# 10397           mL             1            BAG  IV DRIP
#
# [10398 rows x 19 columns]

# %%
df.dtypes
# Out:
# row_id                 int64
# subject_id             int64
# hadm_id                int64
# icustay_id           float64
# startdate             object
# enddate               object
# drug_type             object
# drug                  object
# drug_name_poe         object
# drug_name_generic     object
# formulary_drug_cd     object
# gsn                  float64
# ndc                  float64
# prod_strength         object
# dose_val_rx           object
# dose_unit_rx          object
# form_val_disp         object
# form_unit_disp        object
# route                 object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10398 entries, 0 to 10397
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   row_id             10398 non-null  int64
#  1   subject_id         10398 non-null  int64
#  2   hadm_id            10398 non-null  int64
#  3   icustay_id         7046 non-null   float64
#  4   startdate          10398 non-null  object
#  5   enddate            10397 non-null  object
#  6   drug_type          10398 non-null  object
#  7   drug               10398 non-null  object
#  8   drug_name_poe      5766 non-null   object
#  9   drug_name_generic  5772 non-null   object
#  10  formulary_drug_cd  10397 non-null  object
#  11  gsn                9122 non-null   float64
#  12  ndc                10397 non-null  float64
#  13  prod_strength      10398 non-null  object
#  14  dose_val_rx        10398 non-null  object
#  15  dose_unit_rx       10398 non-null  object
#  16  form_val_disp      10398 non-null  object
#  17  form_unit_disp     10397 non-null  object
#  18  route              10398 non-null  object
# dtypes: float64(3), int64(3), object(13)
# memory usage: 1.5+ MB

# %%
print(f' il y a {df['subject_id'].nunique()} patients dans cette base de données')
# Out:
#  il y a 94 patients dans cette base de données

# %%
df.columns
# Out:
# Index(['row_id', 'subject_id', 'hadm_id', 'icustay_id', 'startdate', 'enddate',
#        'drug_type', 'drug', 'drug_name_poe', 'drug_name_generic',
#        'formulary_drug_cd', 'gsn', 'ndc', 'prod_strength', 'dose_val_rx',
#        'dose_unit_rx', 'form_val_disp', 'form_unit_disp', 'route'],
#       dtype='object')

# %% [markdown]
# ## Construction des ordonances

# %%
def construire_ordonnances(df):
    """
    Reconstitue les ordonnances et génère les paires de médicaments
    pour chaque hadm_id et chaque jour de prescription (startdate).
    
    Paramètres :
        df (DataFrame): Table PRESCRIPTIONS.csv chargée en DataFrame
        
    Retourne :
        DataFrame avec les colonnes : ordonnance_id, hadm_id, ordonnance_date, drug1_name, drug2_name
    """

    # Supprimer les lignes incomplètes
    df = df.dropna(subset=["hadm_id", "startdate", "drug_name_poe"])

    # Assurer que startdate est en datetime
    df["startdate"] = pd.to_datetime(df["startdate"])

    # Créer une colonne de date tronquée (sans l'heure)
    df["ordonnance_date"] = df["startdate"].dt.date

    # Groupement par séjour et jour
    ordonnances = df.groupby(["hadm_id", "ordonnance_date"])["drug_name_poe"].unique().reset_index()

    # Générer un identifiant unique d’ordonnance
    ordonnances["ordonnance_id"] = ["ORD" + str(i).zfill(5) for i in range(len(ordonnances))]

    # Générer les paires de médicaments
    rows = []
    for _, row in ordonnances.iterrows():
        med_list = sorted(row["drug_name_poe"])
        pairs = list(itertools.combinations(med_list, 2))  # paires de 2

        for med1, med2 in pairs:
            rows.append({
                "ordonnance_id": row["ordonnance_id"],
                "hadm_id": row["hadm_id"],
                "ordonnance_date": row["ordonnance_date"],
                "drug1_name": med1,
                "drug2_name": med2
            })

    return pd.DataFrame(rows)

# %%
dataset_interactions = construire_ordonnances(df)

# Aperçu
dataset_interactions.info()
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_2860\2900617541.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["startdate"] = pd.to_datetime(df["startdate"])
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_2860\2900617541.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ordonnance_date"] = df["startdate"].dt.date
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17967 entries, 0 to 17966
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ordonnance_id    17967 non-null  object
#  1   hadm_id          17967 non-null  int64
#  2   ordonnance_date  17967 non-null  object
#  3   drug1_name       17967 non-null  object
#  4   drug2_name       17967 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 702.0+ KB

# %%
dataset_interactions
# Out:
#       ordonnance_id  hadm_id ordonnance_date                   drug1_name  \
# 0          ORD00000   100375      2129-05-02                Acetaminophen
# 1          ORD00000   100375      2129-05-02                Acetaminophen
# 2          ORD00000   100375      2129-05-02                Acetaminophen
# 3          ORD00000   100375      2129-05-02                Acetaminophen
# 4          ORD00000   100375      2129-05-02                Acetaminophen
# ...             ...      ...             ...                          ...
# 17962      ORD01032   199395      2190-07-20                   Ranitidine
# 17963      ORD01032   199395      2190-07-20  Sodium Chloride 0.9%  Flush
# 17964      ORD01033   199395      2190-07-21               Amiodarone HCl
# 17965      ORD01033   199395      2190-07-21               Amiodarone HCl
# 17966      ORD01033   199395      2190-07-21                   Metoprolol
#
#             drug2_name
# 0         Atorvastatin
# 1         Dextrose 50%
# 2      Docusate Sodium
# 3              Insulin
# 4         Pantoprazole
# ...                ...
# 17962         Warfarin
# 17963         Warfarin
# 17964       Metoprolol
# 17965         Warfarin
# 17966         Warfarin
#
# [17967 rows x 5 columns]

# %% [markdown]
# ## Ajouter les type d'interaction

# %%
ddi = pd.read_csv(r'C:\Users\Utilisateur\Desktop\Projet_ordonance\DDI_data.csv')

# %%
ddi
# Out:
#        drug1_id drug2_id             drug1_name            drug2_name  \
# 0       DB00006  DB00346            Bivalirudin             Alfuzosin
# 1       DB00006  DB13783            Bivalirudin            Acemetacin
# 2       DB00006  DB06605            Bivalirudin              Apixaban
# 3       DB00006  DB06695            Bivalirudin  Dabigatran etexilate
# 4       DB00006  DB09075            Bivalirudin              Edoxaban
# ...         ...      ...                    ...                   ...
# 222691  DB13955  DB14033  Estradiol dienanthate  Acetyl sulfisoxazole
# 222692  DB13956  DB14033     Estradiol valerate  Acetyl sulfisoxazole
# 222693  DB14011  DB14033             Nabiximols  Acetyl sulfisoxazole
# 222694  DB14019  DB14033          Fosnetupitant  Acetyl sulfisoxazole
# 222695  DB14033  DB00532   Acetyl sulfisoxazole           Mephenytoin
#
#                     interaction_type
# 0                serum concentration
# 1       risk or severity of bleeding
# 2           anticoagulant activities
# 3           anticoagulant activities
# 4           anticoagulant activities
# ...                              ...
# 222691                    metabolism
# 222692                    metabolism
# 222693                    metabolism
# 222694                    metabolism
# 222695                    metabolism
#
# [222696 rows x 5 columns]

# %%
ddi[ddi['drug1_name'] == 'Atorvastatin']
# Out:
#        drug1_id drug2_id    drug1_name           drug2_name  \
# 172669  DB01076  DB08860  Atorvastatin         Pitavastatin
# 172670  DB01076  DB09296  Atorvastatin           Ombitasvir
# 172671  DB01076  DB09297  Atorvastatin         Paritaprevir
# 172672  DB01076  DB09183  Atorvastatin            Dasabuvir
# 172673  DB01076  DB13345  Atorvastatin  Dihydroergocristine
# ...         ...      ...           ...                  ...
# 172857  DB01076  DB13650  Atorvastatin          Aloglutamol
# 172858  DB01076  DB01390  Atorvastatin   Sodium bicarbonate
# 172859  DB01076  DB03754  Atorvastatin         Tromethamine
# 172860  DB01076  DB09481  Atorvastatin  Magnesium carbonate
# 172861  DB01076  DB06792  Atorvastatin  Lanthanum carbonate
#
#                            interaction_type
# 172669                  serum concentration
# 172670                  serum concentration
# 172671                  serum concentration
# 172672                  serum concentration
# 172673  risk or severity of adverse effects
# ...                                     ...
# 172857                  serum concentration
# 172858                  serum concentration
# 172859                  serum concentration
# 172860                  serum concentration
# 172861                  serum concentration
#
# [193 rows x 5 columns]

# %%
for col in ["drug1_name", "drug2_name"]:
    dataset_interactions[col] = dataset_interactions[col].str.lower().str.strip()
    ddi[col] = ddi[col].str.lower().str.strip()

# %%
# 1er sens
merged_1 = dataset_interactions.merge(ddi, on=["drug1_name", "drug2_name"], how="left")

# Inverser les colonnes pour tester l'autre sens
ordonnances_swapped = dataset_interactions.rename(columns={
    "drug1_name": "drug2_name", "drug2_name": "drug1_name"
})
merged_2 = ordonnances_swapped.merge(ddi, on=["drug1_name", "drug2_name"], how="left")

# Reprendre les colonnes d'origine dans le bon ordre
merged_2 = merged_2.rename(columns={
    "drug1_name": "drug2_name", "drug2_name": "drug1_name"
})

# %%
result = pd.concat([merged_1, merged_2], ignore_index=True)

# Garde uniquement les lignes où une interaction a été trouvée
result = result.dropna(subset=["interaction_type"])  # ou "description", selon ton fichier

# %%
print(result[["ordonnance_id", "drug1_name", "drug2_name", "interaction_type"]])
# Out:
#       ordonnance_id     drug1_name    drug2_name  \
# 0          ORD00000  acetaminophen  atorvastatin
# 68         ORD00006      lorazepam     midazolam
# 163        ORD00018   pantoprazole    tacrolimus
# 179        ORD00019   clotrimazole      diazepam
# 186        ORD00019   clotrimazole   ondansetron
# ...             ...            ...           ...
# 35889      ORD01032     furosemide    metoprolol
# 35897      ORD01032      glipizide    metoprolol
# 35901      ORD01032      glipizide    ranitidine
# 35903      ORD01032      glipizide      warfarin
# 35930      ORD01032     ranitidine      warfarin
#
#                           interaction_type
# 0      risk or severity of adverse effects
# 68     risk or severity of adverse effects
# 163                    serum concentration
# 179                             metabolism
# 186                             metabolism
# ...                                    ...
# 35889  risk or severity of adverse effects
# 35897              hypoglycemic activities
# 35901                  serum concentration
# 35903             anticoagulant activities
# 35930                  serum concentration
#
# [978 rows x 4 columns]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 978 entries, 0 to 35930
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ordonnance_id     978 non-null    object
#  1   hadm_id           978 non-null    int64
#  2   ordonnance_date   978 non-null    object
#  3   drug1_name        978 non-null    object
#  4   drug2_name        978 non-null    object
#  5   drug1_id          978 non-null    object
#  6   drug2_id          978 non-null    object
#  7   interaction_type  978 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 68.8+ KB

# %%
result
# Out:
#       ordonnance_id  hadm_id ordonnance_date     drug1_name    drug2_name  \
# 0          ORD00000   100375      2129-05-02  acetaminophen  atorvastatin
# 68         ORD00006   100969      2142-11-28      lorazepam     midazolam
# 163        ORD00018   101361      2145-12-15   pantoprazole    tacrolimus
# 179        ORD00019   102203      2127-07-23   clotrimazole      diazepam
# 186        ORD00019   102203      2127-07-23   clotrimazole   ondansetron
# ...             ...      ...             ...            ...           ...
# 35889      ORD01032   199395      2190-07-20     furosemide    metoprolol
# 35897      ORD01032   199395      2190-07-20      glipizide    metoprolol
# 35901      ORD01032   199395      2190-07-20      glipizide    ranitidine
# 35903      ORD01032   199395      2190-07-20      glipizide      warfarin
# 35930      ORD01032   199395      2190-07-20     ranitidine      warfarin
#
#       drug1_id drug2_id                     interaction_type
# 0      DB00316  DB01076  risk or severity of adverse effects
# 68     DB00186  DB00683  risk or severity of adverse effects
# 163    DB00213  DB00864                  serum concentration
# 179    DB00257  DB00829                           metabolism
# 186    DB00257  DB00904                           metabolism
# ...        ...      ...                                  ...
# 35889  DB00264  DB00695  risk or severity of adverse effects
# 35897  DB00264  DB01067              hypoglycemic activities
# 35901  DB00863  DB01067                  serum concentration
# 35903  DB00682  DB01067             anticoagulant activities
# 35930  DB00682  DB00863                  serum concentration
#
# [978 rows x 8 columns]

# %% [markdown]
# # On remarque q'on a 978 interactions détecté

# %% [markdown]
# ## Ajouter une description pour chaque interaction

# %%
file_path = Path(r"C:\Users\Utilisateur\Desktop\Projet_ordonance\drugbank.xml\drugbank.xml")
tree = ET.parse(file_path)             # peut lever ET.XMLSyntaxError si le fichier est corrompu
root = tree.getroot()

# %%
NS = {"db": "http://www.drugbank.ca"}

# %%
records = []

for drug in root.findall(".//db:drug", NS):
    this_id   = drug.findtext(".//db:drugbank-id[@primary='true']", namespaces=NS)
    this_name = drug.findtext(".//db:name", namespaces=NS)

    # 3a.  Parcours des <drug-interaction> de ce médicament
    for di in drug.findall(".//db:drug-interactions/db:drug-interaction", NS):
        partner_id   = di.findtext("db:drugbank-id", namespaces=NS)
        partner_name = di.findtext("db:name", namespaces=NS)
        description  = di.findtext("db:description", namespaces=NS)

        records.append(
            {
                "drug_id":        this_id,
                "drug_name":      this_name,
                "partner_id":     partner_id,
                "partner_name":   partner_name,
                "description":    description,
            }
        )

# ------------------------------
# 4.  Option : transformer en DataFrame pandas
# ------------------------------
df = pd.DataFrame(records)
print(df.head())
# Out:
#    drug_id  drug_name partner_id     partner_name  \
# 0  DB00001  Lepirudin    DB01323  St. John's Wort
# 1  DB00001  Lepirudin    DB00346        Alfuzosin
# 2  DB00001  Lepirudin    DB13783       Acemetacin
# 3  DB00001  Lepirudin    DB06605         Apixaban
# 4  DB00001  Lepirudin    DB09075         Edoxaban
#
#                                          description
# 0  The metabolism of Lepirudin can be increased w...
# 1  The serum concentration of Alfuzosin can be in...
# 2  The risk or severity of bleeding can be increa...
# 3  Apixaban may increase the anticoagulant activi...
# 4  Edoxaban may increase the anticoagulant activi...

# %%
df.shape
# Out:
# (658079, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 658079 entries, 0 to 658078
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   drug_id       658079 non-null  object
#  1   drug_name     658079 non-null  object
#  2   partner_id    658079 non-null  object
#  3   partner_name  658079 non-null  object
#  4   description   658079 non-null  object
# dtypes: object(5)
# memory usage: 25.1+ MB

# %%
df
# Out:
#         drug_id    drug_name partner_id     partner_name  \
# 0       DB00001    Lepirudin    DB01323  St. John's Wort
# 1       DB00001    Lepirudin    DB00346        Alfuzosin
# 2       DB00001    Lepirudin    DB13783       Acemetacin
# 3       DB00001    Lepirudin    DB06605         Apixaban
# 4       DB00001    Lepirudin    DB09075         Edoxaban
# ...         ...          ...        ...              ...
# 658074  DB13929  Relcovaptan    DB12749   Butylphthalide
# 658075  DB13929  Relcovaptan    DB12771   Hydroxytyrosol
# 658076  DB13929  Relcovaptan    DB13036       Ramatroban
# 658077  DB13929  Relcovaptan    DB13400      Linsidomine
# 658078  DB13929  Relcovaptan    DB13510       Buflomedil
#
#                                               description
# 0       The metabolism of Lepirudin can be increased w...
# 1       The serum concentration of Alfuzosin can be in...
# 2       The risk or severity of bleeding can be increa...
# 3       Apixaban may increase the anticoagulant activi...
# 4       Edoxaban may increase the anticoagulant activi...
# ...                                                   ...
# 658074  Butylphthalide may increase the antiplatelet a...
# 658075  Hydroxytyrosol may increase the antiplatelet a...
# 658076  Ramatroban may increase the antiplatelet activ...
# 658077  Linsidomine may increase the antiplatelet acti...
# 658078  Buflomedil may increase the antiplatelet activ...
#
# [658079 rows x 5 columns]

# %% [markdown]
# ### On nettoie les données des deux tbale pour les joindre

# %%
description = df[['drug_name' , 'partner_name','description']]
description
# Out:
#           drug_name     partner_name  \
# 0         Lepirudin  St. John's Wort
# 1         Lepirudin        Alfuzosin
# 2         Lepirudin       Acemetacin
# 3         Lepirudin         Apixaban
# 4         Lepirudin         Edoxaban
# ...             ...              ...
# 658074  Relcovaptan   Butylphthalide
# 658075  Relcovaptan   Hydroxytyrosol
# 658076  Relcovaptan       Ramatroban
# 658077  Relcovaptan      Linsidomine
# 658078  Relcovaptan       Buflomedil
#
#                                               description
# 0       The metabolism of Lepirudin can be increased w...
# 1       The serum concentration of Alfuzosin can be in...
# 2       The risk or severity of bleeding can be increa...
# 3       Apixaban may increase the anticoagulant activi...
# 4       Edoxaban may increase the anticoagulant activi...
# ...                                                   ...
# 658074  Butylphthalide may increase the antiplatelet a...
# 658075  Hydroxytyrosol may increase the antiplatelet a...
# 658076  Ramatroban may increase the antiplatelet activ...
# 658077  Linsidomine may increase the antiplatelet acti...
# 658078  Buflomedil may increase the antiplatelet activ...
#
# [658079 rows x 3 columns]

# %%
description = description.rename(columns={'drug_name' : 'drug1_name','partner_name': 'drug2_name'})
print(description.columns.tolist())
# Out:
# ['drug1_name', 'drug2_name', 'description']

# %%
cols = ["drug1_name", "drug2_name"]

# 4) Nettoyage strip + lower sur ces colonnes
description[cols] = description[cols].apply(
    lambda s: s.str.strip().str.lower()
)
description
# Out:
#          drug1_name       drug2_name  \
# 0         lepirudin  st. john's wort
# 1         lepirudin        alfuzosin
# 2         lepirudin       acemetacin
# 3         lepirudin         apixaban
# 4         lepirudin         edoxaban
# ...             ...              ...
# 658074  relcovaptan   butylphthalide
# 658075  relcovaptan   hydroxytyrosol
# 658076  relcovaptan       ramatroban
# 658077  relcovaptan      linsidomine
# 658078  relcovaptan       buflomedil
#
#                                               description
# 0       The metabolism of Lepirudin can be increased w...
# 1       The serum concentration of Alfuzosin can be in...
# 2       The risk or severity of bleeding can be increa...
# 3       Apixaban may increase the anticoagulant activi...
# 4       Edoxaban may increase the anticoagulant activi...
# ...                                                   ...
# 658074  Butylphthalide may increase the antiplatelet a...
# 658075  Hydroxytyrosol may increase the antiplatelet a...
# 658076  Ramatroban may increase the antiplatelet activ...
# 658077  Linsidomine may increase the antiplatelet acti...
# 658078  Buflomedil may increase the antiplatelet activ...
#
# [658079 rows x 3 columns]

# %%
for d in (result, description):
    d["key"] = d[["drug1_name", "drug2_name"]].apply(
        lambda r: "|".join(sorted(map(str.lower, r))),        # ex. "atorvastatin|paracetamol"
        axis=1
    )

# 2) Jointure et récupération de la description ---------------
result = result.merge(
    description[["key", "description"]].drop_duplicates("key"),
    on="key",
    how="left"            # garde toutes les observations
).drop(columns="key")     #

# %%
result.drop(columns=['drug1_id','drug2_id'],axis=1,inplace=True)

# %%
result
# Out:
#     ordonnance_id  hadm_id ordonnance_date     drug1_name    drug2_name  \
# 0        ORD00000   100375      2129-05-02  acetaminophen  atorvastatin
# 1        ORD00006   100969      2142-11-28      lorazepam     midazolam
# 2        ORD00018   101361      2145-12-15   pantoprazole    tacrolimus
# 3        ORD00019   102203      2127-07-23   clotrimazole      diazepam
# 4        ORD00019   102203      2127-07-23   clotrimazole   ondansetron
# ..            ...      ...             ...            ...           ...
# 973      ORD01032   199395      2190-07-20     furosemide    metoprolol
# 974      ORD01032   199395      2190-07-20      glipizide    metoprolol
# 975      ORD01032   199395      2190-07-20      glipizide    ranitidine
# 976      ORD01032   199395      2190-07-20      glipizide      warfarin
# 977      ORD01032   199395      2190-07-20     ranitidine      warfarin
#
#                         interaction_type  \
# 0    risk or severity of adverse effects
# 1    risk or severity of adverse effects
# 2                    serum concentration
# 3                             metabolism
# 4                             metabolism
# ..                                   ...
# 973  risk or severity of adverse effects
# 974              hypoglycemic activities
# 975                  serum concentration
# 976             anticoagulant activities
# 977                  serum concentration
#
#                                            description
# 0    The risk or severity of adverse effects can be...
# 1    The risk or severity of adverse effects can be...
# 2    The serum concentration of Tacrolimus can be i...
# 3    The metabolism of Diazepam can be decreased wh...
# 4    The metabolism of Ondansetron can be decreased...
# ..                                                 ...
# 973  The risk or severity of adverse effects can be...
# 974  Metoprolol may increase the hypoglycemic activ...
# 975  The serum concentration of Glipizide can be in...
# 976  Glipizide may increase the anticoagulant activ...
# 977  The serum concentration of Warfarin can be inc...
#
# [978 rows x 7 columns]

# %% [markdown]
# ## Ajout du niveau de gravité pour chaque interaction médicamenteuse

# %%
all_filles = glob.glob(r'C:\Users\Utilisateur\Desktop\Projet_ordonance\Level\*.csv')

# %%
ddi_all = pd.concat([pd.read_csv(f) for f in all_filles], ignore_index=True)

# %%
ddi_all
# Out:
#         DDInterID_A                Drug_A  DDInterID_B        Drug_B     Level
# 0       DDInter1263            Naltrexone     DDInter1      Abacavir  Moderate
# 1          DDInter1              Abacavir  DDInter1348      Orlistat  Moderate
# 2         DDInter58    Aluminum hydroxide   DDInter582  Dolutegravir     Major
# 3        DDInter112            Aprepitant   DDInter582  Dolutegravir     Minor
# 4        DDInter138           Attapulgite   DDInter582  Dolutegravir     Major
# ...             ...                   ...          ...           ...       ...
# 222378   DDInter513         Dexamethasone   DDInter801     Galactose   Unknown
# 222379  DDInter1683    Sodium bicarbonate   DDInter801     Galactose   Unknown
# 222380   DDInter317              Cefepime   DDInter801     Galactose   Unknown
# 222381  DDInter1906  Ursodeoxycholic acid   DDInter801     Galactose   Unknown
# 222382  DDInter1663             Sevelamer   DDInter766   Fluticasone   Unknown
#
# [222383 rows x 5 columns]

# %%
Level = ddi_all[['Drug_A','Drug_B','Level']]
Level
# Out:
#                       Drug_A        Drug_B     Level
# 0                 Naltrexone      Abacavir  Moderate
# 1                   Abacavir      Orlistat  Moderate
# 2         Aluminum hydroxide  Dolutegravir     Major
# 3                 Aprepitant  Dolutegravir     Minor
# 4                Attapulgite  Dolutegravir     Major
# ...                      ...           ...       ...
# 222378         Dexamethasone     Galactose   Unknown
# 222379    Sodium bicarbonate     Galactose   Unknown
# 222380              Cefepime     Galactose   Unknown
# 222381  Ursodeoxycholic acid     Galactose   Unknown
# 222382             Sevelamer   Fluticasone   Unknown
#
# [222383 rows x 3 columns]

# %%
Level.rename(columns={'Drug_A':'drug1_name','Drug_B':'drug2_name'},inplace=True)
Level
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_2860\3723328708.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Level.rename(columns={'Drug_A':'drug1_name','Drug_B':'drug2_name'},inplace=True)
#                   drug1_name    drug2_name     Level
# 0                 Naltrexone      Abacavir  Moderate
# 1                   Abacavir      Orlistat  Moderate
# 2         Aluminum hydroxide  Dolutegravir     Major
# 3                 Aprepitant  Dolutegravir     Minor
# 4                Attapulgite  Dolutegravir     Major
# ...                      ...           ...       ...
# 222378         Dexamethasone     Galactose   Unknown
# 222379    Sodium bicarbonate     Galactose   Unknown
# 222380              Cefepime     Galactose   Unknown
# 222381  Ursodeoxycholic acid     Galactose   Unknown
# 222382             Sevelamer   Fluticasone   Unknown
#
# [222383 rows x 3 columns]

# %%
for d in (result, Level):
    d["key"] = d[["drug1_name", "drug2_name"]].apply(
        lambda r: "|".join(sorted(map(str.lower, r))),        # ex. "atorvastatin|paracetamol"
        axis=1
    )

# 2) Jointure et récupération de la description ---------------
result = result.merge(
    Level[["key", "Level"]].drop_duplicates("key"),
    on="key",
    how="left"            # garde toutes les observations
).drop(columns="key")     #
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_2860\2533748450.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["key"] = d[["drug1_name", "drug2_name"]].apply(

# %%
Level
# Out:
#                   drug1_name    drug2_name     Level  \
# 0                 Naltrexone      Abacavir  Moderate
# 1                   Abacavir      Orlistat  Moderate
# 2         Aluminum hydroxide  Dolutegravir     Major
# 3                 Aprepitant  Dolutegravir     Minor
# 4                Attapulgite  Dolutegravir     Major
# ...                      ...           ...       ...
# 222378         Dexamethasone     Galactose   Unknown
# 222379    Sodium bicarbonate     Galactose   Unknown
# 222380              Cefepime     Galactose   Unknown
# 222381  Ursodeoxycholic acid     Galactose   Unknown
# 222382             Sevelamer   Fluticasone   Unknown
#
#                                     key
# 0                   abacavir|naltrexone
# 1                     abacavir|orlistat
# 2       aluminum hydroxide|dolutegravir
# 3               aprepitant|dolutegravir
# 4              attapulgite|dolutegravir
# ...                                 ...
# 222378          dexamethasone|galactose
# 222379     galactose|sodium bicarbonate
# 222380               cefepime|galactose
# 222381   galactose|ursodeoxycholic acid
# 222382            fluticasone|sevelamer
#
# [222383 rows x 4 columns]

# %%
result
# Out:
#     ordonnance_id  hadm_id ordonnance_date     drug1_name    drug2_name  \
# 0        ORD00000   100375      2129-05-02  acetaminophen  atorvastatin
# 1        ORD00006   100969      2142-11-28      lorazepam     midazolam
# 2        ORD00018   101361      2145-12-15   pantoprazole    tacrolimus
# 3        ORD00019   102203      2127-07-23   clotrimazole      diazepam
# 4        ORD00019   102203      2127-07-23   clotrimazole   ondansetron
# ..            ...      ...             ...            ...           ...
# 973      ORD01032   199395      2190-07-20     furosemide    metoprolol
# 974      ORD01032   199395      2190-07-20      glipizide    metoprolol
# 975      ORD01032   199395      2190-07-20      glipizide    ranitidine
# 976      ORD01032   199395      2190-07-20      glipizide      warfarin
# 977      ORD01032   199395      2190-07-20     ranitidine      warfarin
#
#                         interaction_type  \
# 0    risk or severity of adverse effects
# 1    risk or severity of adverse effects
# 2                    serum concentration
# 3                             metabolism
# 4                             metabolism
# ..                                   ...
# 973  risk or severity of adverse effects
# 974              hypoglycemic activities
# 975                  serum concentration
# 976             anticoagulant activities
# 977                  serum concentration
#
#                                            description     Level
# 0    The risk or severity of adverse effects can be...       NaN
# 1    The risk or severity of adverse effects can be...       NaN
# 2    The serum concentration of Tacrolimus can be i...  Moderate
# 3    The metabolism of Diazepam can be decreased wh...  Moderate
# 4    The metabolism of Ondansetron can be decreased...   Unknown
# ..                                                 ...       ...
# 973  The risk or severity of adverse effects can be...       NaN
# 974  Metoprolol may increase the hypoglycemic activ...  Moderate
# 975  The serum concentration of Glipizide can be in...  Moderate
# 976  Glipizide may increase the anticoagulant activ...  Moderate
# 977  The serum concentration of Warfarin can be inc...  Moderate
#
# [978 rows x 8 columns]

# %%
result['Level'].isnull().sum()
# Out:
# 617

# %%
Level['Level'].value_counts()
# Out:
# Level
# Moderate    130367
# Unknown      47182
# Major        33896
# Minor        10938
# Name: count, dtype: int64

# %%
Level['Level'].isnull().sum()
# Out:
# 0

# %%
nb_total = len(result)
nb_connus = result["Level"].notna().sum()
nb_inconnus = result["Level"].isna().sum()

print(f"Total paires analysées : {nb_total}")
print(f"Interactions trouvées  : {nb_connus}")
print(f"Interactions manquantes : {nb_inconnus}")
# Out:
# Total paires analysées : 978
# Interactions trouvées  : 361
# Interactions manquantes : 617
